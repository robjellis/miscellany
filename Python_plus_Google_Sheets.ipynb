# %% [markdown]
# # Example code
# Notes:
# - For a new connection, must first follow all steps exactly from [here](https://developers.google.com/sheets/api/quickstart/python#step_1_turn_on_the_api_name).
# - The **credentials.json** file should live in the same directory as the notebook; alternatively, specify the full path to the file in the `client.flow_from_clientsecrets` line of code.

# %% [markdown]
# ### Imports

# %%
# Standard
import pandas as pd
import numpy as np

# Google stuff
from apiclient.discovery import build
from httplib2 import Http
from oauth2client import file, client, tools

# %%
# Setup the Sheets API; just do this once
SCOPES = 'https://www.googleapis.com/auth/spreadsheets.readonly'
store = file.Storage('token.json')
creds = store.get()

if not creds or creds.invalid:
    flow = client.flow_from_clientsecrets('credentials.json', SCOPES)
    creds = tools.run_flow(flow, store)
service = build('sheets', 'v4', http=creds.authorize(Http()))

# %% [markdown]
# ### Extract the data and put into a dataframe

# %% [markdown]
# Example uses [this sheet](https://docs.google.com/spreadsheets/d/1BxiMVs0XRA5nFMdKvBdBZjgmUUqptlbs74OgvE2upms/edit#gid=0):

# %%
SPREADSHEET_ID_TEST = '1BxiMVs0XRA5nFMdKvBdBZjgmUUqptlbs74OgvE2upms'
RANGE_NAME_TEST = 'Class Data!A1:F' # start with first row so we capture headers

# %% [markdown]
# This could be put into a function:

# %%
# capture all the data
result = service.spreadsheets().values().get(spreadsheetId = SPREADSHEET_ID_TEST,
                                         range=RANGE_NAME_TEST).execute()

# column names are in first row
col_names = result['values'][0]
ncols = len(col_names)

# how many rows (excluding header row)?
nrows = len(result['values']) - 1

print('Dataframe will be {} rows by {} columns.'.format(nrows,ncols))

# make an empty dataframe to store data
df = pd.DataFrame(np.zeros((nrows,ncols)))

# fill the data frame
for i in np.arange(nrows):
    this_row = result['values'][i+1]

    for j in np.arange(ncols):
        df.iloc[i,j] = this_row[j]

# add the column names
df.columns = col_names

df
# Out:
# Dataframe will be 30 rows by 6 columns.
#    Student Name  Gender   Class Level Home State    Major  \
# 0     Alexandra  Female     4. Senior         CA  English
# 1        Andrew    Male   1. Freshman         SD     Math
# 2          Anna  Female   1. Freshman         NC  English
# 3         Becky  Female  2. Sophomore         SD      Art
# 4      Benjamin    Male     4. Senior         WI  English
# 5          Carl    Male     3. Junior         MD      Art
# 6        Carrie  Female     3. Junior         NE  English
# 7       Dorothy  Female     4. Senior         MD     Math
# 8         Dylan    Male   1. Freshman         MA     Math
# 9        Edward    Male     3. Junior         FL  English
# 10        Ellen  Female   1. Freshman         WI  Physics
# 11        Fiona  Female   1. Freshman         MA      Art
# 12         John    Male     3. Junior         CA  Physics
# 13     Jonathan    Male  2. Sophomore         SC     Math
# 14       Joseph    Male   1. Freshman         AK  English
# 15    Josephine  Female   1. Freshman         NY     Math
# 16        Karen  Female  2. Sophomore         NH  English
# 17        Kevin    Male  2. Sophomore         NE  Physics
# 18         Lisa  Female     3. Junior         SC      Art
# 19         Mary  Female  2. Sophomore         AK  Physics
# 20      Maureen  Female   1. Freshman         CA  Physics
# 21         Nick    Male     4. Senior         NY      Art
# 22       Olivia  Female     4. Senior         NC  Physics
# 23       Pamela  Female     3. Junior         RI     Math
# 24      Patrick    Male   1. Freshman         NY      Art
# 25       Robert    Male   1. Freshman         CA  English
# 26         Sean    Male   1. Freshman         NH  Physics
# 27        Stacy  Female   1. Freshman         NY     Math
# 28       Thomas    Male  2. Sophomore         RI      Art
# 29         Will    Male     4. Senior         FL     Math
#
#    Extracurricular Activity
# 0                Drama Club
# 1                  Lacrosse
# 2                Basketball
# 3                  Baseball
# 4                Basketball
# 5                    Debate
# 6             Track & Field
# 7                  Lacrosse
# 8                  Baseball
# 9                Drama Club
# 10               Drama Club
# 11                   Debate
# 12               Basketball
# 13                   Debate
# 14               Drama Club
# 15                   Debate
# 16               Basketball
# 17               Drama Club
# 18                 Lacrosse
# 19            Track & Field
# 20               Basketball
# 21                 Baseball
# 22            Track & Field
# 23                 Baseball
# 24                 Lacrosse
# 25            Track & Field
# 26            Track & Field
# 27                 Baseball
# 28                 Lacrosse
# 29                   Debate
